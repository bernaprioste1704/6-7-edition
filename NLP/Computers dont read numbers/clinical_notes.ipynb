# %% [markdown]
# # Treat Clinical notes
#
# **COLAB link** https://colab.research.google.com/github/samsung-ai-course/6-7-edition/blob/main/NLP/Computers%20dont%20read%20numbers/clinical_notes.ipynb

# %%
# Standard library imports
import re
import requests 
from tqdm import tqdm 

# Data manipulation libraries
import pandas as pd
import numpy as np

# Data visualization libraries
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from PIL import Image


# NLTK imports
import nltk
from nltk.corpus import stopwords, wordnet
from nltk.stem import WordNetLemmatizer

# Download required NLTK data files (run only once)
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Utilizador\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Utilizador\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Utilizador\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Utilizador\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Utilizador\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %% [markdown]
# # Read files into a Data Frame

# %%
files_list = requests.get("https://raw.githubusercontent.com/samsung-ai-course/6-7-edition/refs/heads/main/NLP/Computers%20dont%20read%20numbers/directories.txt")
files_list  = files_list.text.split("\n")
notes = []
# run this cells only once this can be blocked by github if a lot of runs are tried
for file in tqdm(files_list[:15]):

    note = requests.get("https://raw.githubusercontent.com/samsung-ai-course/6-7-edition/refs/heads/main/NLP/Computers%20dont%20read%20numbers/data/"+file)
    notes.append(note.text)
# Out:
# 100%|██████████| 15/15 [00:00<00:00, 21.70it/s]

# %%
notes
# Out:
# [" \nName:  ___                  Unit No:   ___\n \nAdmission Date:  ___              Discharge Date:   ___\n \nDate of Birth:  ___             Sex:   F\n \nService: MEDICINE\n \nAllergies: \nCodeine\n \nAttending: ___\n \nChief Complaint:\nI feel shaky\n \nMajor Surgical or Invasive Procedure:\nNone\n \nHistory of Present Illness:\nPt is a ___ year old woman who presents to ED from opthomologists \noffice after she began feeling shaky, nauseous and weak. Blood \nsugar was noted to be 308 and she was sent to the ED. She felt \nnauseous this morning and did not eat breakfast or take her \nmedications, including her insulin. She notes she has been \nfeeling generally weak for the last month and fatigued for about \n6 months. She has been taking prednisone daily since a \nhospitalization in ___ for PNA and new onset AFib. \nAdditionally, she developed sunburn over both feet 5 weeks ago, \nand developed ulcerating blisters for which she has been taking \namoxicillin for the last 5 weeks. She has noted diarrhea with \nthe amoxicillin. She denies recent fevers or chills. She \nbelieves her foot blisters are healing and denies pain. No chest \npain. Noticed foul smelling urine this morning.     \n.  \nIn the ED, initial vs were: T97.9 P 74 BP 150/60 R 18 O2 sat \n97%2L. UA was notable for likely infection. Labs showed BG 361, \nanion gap of 21, and positive ketones in the urine, and lactate \nof 4.6. Patient was given her home insulin dose of 42 units \n70/30 and 1 g ceftriaxone for presumed UTI. Pt recieved total of \n2 L IVF's and her BG decreased to 254, gap reduced to 18 and \nlactate decreased to 4.0. She was transferred to the floor for \nfurther management.   \n.  \nReview of systems:  \n(+) Per HPI. Also notes recent weight gain while on prednisone \nalong with fatigue and weakness. \n(-) Denies fever, chills, or recent weight loss. Denies \nheadache, sinus tenderness, rhinorrhea or congestion. Denied \ncough, shortness of breath. Denied chest pain or tightness, \npalpitations. Denied arthralgias or myalgias.  \n \nPast Medical History:\n-IDDM c/b retinopathy\n-HTN\n-AFib, diagnosed during hospitalization in ___\n-s/p hysterectomy, rt breast benign tumor removal, and \ndebridement of left foot infection \n \nSocial History:\n___\nFamily History:\n- 6 children, one daughter died last year from ?complications of \nhemachromatosis (runs in late husband's side of family)\n- Mother died of complications of diabetes, another brother with \nDM\n- No known history of cardiovascular disease or stroke\n \nPhysical Exam:\nFEX ON ADMISSION\nVitals: T: 98.4 BP: 176/96 P: 86 R: 20 O2:  96%RA \nGeneral: Pleasant elderly woman. Alert and oriented. Somewhat \ntremulous but appears comfortable.  \nHEENT: Sclera anicteric, MMM, oropharynx clear  \nNeck: supple, JVP not elevated, diffusely enlarged nontender \nthyroid   \nLungs: Wet crackles at bases, Nonlabored and speaking in full \nsentences.  \nCV: Regular rate and rhythm, normal S1 + S2, no murmurs, rubs, \ngallops  \nAbdomen: Obese, moderately distended. Positive bowel sounds. No \nfluid shift noted. Non-tender, difficult to evaluate for \norganomegaly  \nExt: ___ nonpitting edema of lower extremities. No clubbing or \ncyanosis. 1+ DP pulses. 2+ radial.\nNeuro: CNs2-12 intact, Strength ___ throughout. No gross sensory \nloss.\nSkin: Poorly demarcated erythema over bilateral lower \nextremities up to mid shin. 1-2cm healing ulcer on dorsum of \nleft foot, and smaller 1 cm healing ulcer on dorsum of rt foot. \nDiffusely dry skin with leathery changes over the waistband area \non abdomen on right side.\n\nFEX ON DISCHARGE\nVitals: T: 97.9 BP: 127/59 P: 73 R: 20 O2:  93%RA \nGeneral: Pleasant elderly woman. Alert and oriented. \nComfortable.\nHEENT: Sclera anicteric, MMM, oropharynx clear  \nNeck: supple, JVP not elevated, diffusely enlarged nontender \nthyroid   \nLungs: Wet crackles halfway up bilaterally, mild expiratory \nwheeze anteriorly. Nonlabored and speaking in full sentences.  \nCV: ...
#  " \nName:  ___                  Unit No:   ___\n \nAdmission Date:  ___              Discharge Date:   ___\n \nDate of Birth:  ___             Sex:   M\n \nService: MEDICINE\n \nAllergies: \nDemerol\n \nAttending: ___.\n \nChief Complaint:\nDyspnea\n \nMajor Surgical or Invasive Procedure:\nBronchoscopy\n\n \nHistory of Present Illness:\nThis is an ___ yo M with history of mild dementia, possible \ndiastolic dysfunction, who is admitted with subjective shortness \nof breath. The patient has been complaining to his outpatient \nprovider about dyspnea, cardiac work up has been negative, so a \nCT chest was ordered. There was no PE, however, there was \nevidence of a large pulmonary mass with evidence of bony \nmetastasis. He is admitted for further\nwork up and evaluation. Of note, the family has requested that \nthey tell the patient on their terms of his diagnosis, so at the \ntime of this admission note, the patient is unaware of the CT \nfindings.\n\nIn the ED, initial VS were stable, with respiratory rate < 18. \nOn the floor, the patient continues to be stable with complaints \nofmild dyspnea, which he notes is worse with exertion, \nespecially with stair\nclimbing. He says this has been going on for months. He also \nnotes a dry cough for about that long. He denies unintentional \nweight loss, anorexia, nightsweats or other B symptoms. He \ndenies sick contacts, fevers/chills or URI symptoms.\n\nROS:\n(+) Per HPI\n(-) Denies fever, chills, night sweats, recent weight loss or \ngain. Denies headache, sinus tenderness, rhinorrhea or \ncongestion. Denied chest pain or tightness, palpitations. Denied \nnausea, vomiting, diarrhea, constipation or abdominal pain. No \nrecent change in bowel or bladder habits. No dysuria. Denied \narthralgias or myalgias.\n \nPast Medical History:\ngastroesophageal reflux disease\nhypercholesterolemia\ns/p LGIB with discovery of large colonic lipoma at hepatic \nflexure that was removed by right transverse colectomy in ___\ntransurethral resection of prostate\nTIA in ___\nFrequent UTI's\nLeft shoulder impingement syndrome/full thickness rotator cuff \ntear\n \nSocial History:\n___\nFamily History:\nstrong family history of diabetes mellitus, and \nhypercholesterolemia. His sister deceased of ___ at age \n___. Question of renal disease in the family.\n \nPhysical Exam:\nVS: T 98.6max, 97.3current, BP ___, HR 79 RR 18, 02sat 97% on \n2L\nGEN: NAD, resting comfortably watching TV in chair, NC 02 on.\nHEENT: Pupils unequel, R, RRL, Left surgical pupil. No \ninjections, no icterus. OP wnl. Neck supple, nontender, no JVD, \nno bruits.\nPULM: mild dry cough, Bibasilar rales 112 way up back, no focal \nfindings.\nCARD: RRR, s 1, s2 wnl, no mlrlg\nABD: obese, firm, nontender, BS+, midline surgical scar, old.\nEXT: DP 1 +, 2+pitting edema up to knees\nNEURO: CNII-XI1 intact. A+Ox3, poor memory.\nPSYCH: appropriate affect\n \nPertinent Results:\n___ 01:30PM BLOOD WBC-15.1* RBC-4.32* Hgb-13.1* Hct-38.3* \nMCV-89 MCH-30.4 MCHC-34.2 RDW-13.9 Plt ___\n___ 06:45AM BLOOD WBC-13.8* RBC-3.98* Hgb-12.1* Hct-35.4* \nMCV-89 MCH-30.5 MCHC-34.3 RDW-14.5 Plt ___\n___ 05:00AM BLOOD WBC-11.1* RBC-3.83* Hgb-11.5* Hct-34.0* \nMCV-89 MCH-30.0 MCHC-33.8 RDW-14.4 Plt ___\n___ 01:30PM BLOOD Neuts-54 Bands-9* ___ Monos-11 \nEos-2 Baso-0 Atyps-1* Metas-3* Myelos-0\n___ 01:30PM BLOOD Hypochr-NORMAL Anisocy-1+ Poiklo-1+ \nMacrocy-NORMAL Microcy-NORMAL Polychr-1+ Schisto-1+\n___ 01:30PM BLOOD PTT-24.2\n___ 01:30PM BLOOD Plt Smr-LOW Plt ___\n___ 08:00PM BLOOD ___ PTT-24.3 ___\n___ 06:45AM BLOOD Plt ___\n___ 05:00AM BLOOD Plt ___\n___ 01:30PM BLOOD D-Dimer-4038*\n___ 01:30PM BLOOD UreaN-41* Creat-1.4* Na-139 K-4.1 Cl-97 \nHCO3-29 AnGap-17\n___ 06:45AM BLOOD Glucose-90 UreaN-42* Creat-1.4* Na-139 \nK-4.2 Cl-98 HCO3-29 AnGap-16\n___ 05:00AM BLOOD Glucose-106* UreaN-47* Creat-1.3* Na-139 \nK-4.3 Cl-96 HCO3-30 AnGap-17\n___ 01:30PM BLOOD ALT-370* AST-342* CK(CPK)-139 \nAlkPhos-136* TotBili-1.0 DirBili-0.7* IndBili-0.3\n___ 06:45AM BLOOD  ...
#  ' \nName:  ___                  Unit No:   ___\n \nAdmission Date:  ___              Discharge Date:   ___\n \nDate of Birth:  ___             Sex:   F\n \nService: ORTHOPAEDICS\n \nAllergies: \nNo Known Allergies / Adverse Drug Reactions\n \nAttending: ___.\n \nChief Complaint:\nRLE pain\n \nMajor Surgical or Invasive Procedure:\nRight short trochanteric fixation nail\n\n \nHistory of Present Illness:\n___, blown over by gust of wind w/R ITFx now s/p short TFN\n \nPast Medical History:\nMedHx:\n-HTN\n-Hypercholesterolemia\n-Eczema\n-Osteopenia\n-Diverticulosis\n-Hyperparathyroidism\n-Mild aortic stenosis\n-Hypothyroidism\nSurgHx:\n-Appendectomy \n-___ procedure for squamous cell carcinoma\n \nSocial History:\n___\nFamily History:\nMother deceased with HTN, CAD. Father deceased with gastric \ncancer. Sister generally healthy. \n \nBrief Hospital Course:\nThe patient presented to the emergency department and was \nevaluated by the orthopedic surgery team. The patient was found \nto have right intertrochanteric femur fracture and was admitted \nto the orthopedic surgery service. The patient was taken to the \noperating room on ___ for right short trochanteric fixation \nnail, which the patient tolerated well. For full details of the \nprocedure please see the separately dictated operative report. \nThe patient was taken from the OR to the PACU in stable \ncondition and after satisfactory recovery from anesthesia was \ntransferred to the floor. The patient was initially given IV \nfluids and IV pain medications, and progressed to a regular diet \nand oral medications by POD#1. The patient was given \n___ antibiotics and anticoagulation per routine. The \npatient\'s home medications were continued throughout this \nhospitalization. The patient worked with ___ who determined that \ndischarge to rehab was appropriate. The ___ hospital \ncourse was otherwise unremarkable.\n\nAt the time of discharge the patient\'s pain was well controlled \nwith oral medications, incisions were clean/dry/intact, and the \npatient was voiding/moving bowels spontaneously. The patient is \nweight bearing as tolerated in the right lower extremity, and \nwill be discharged on Lovenox for DVT prophylaxis. The patient \nwill follow up with Dr. ___ routine. A thorough \ndiscussion was had with the patient regarding the diagnosis and \nexpected post-discharge course including reasons to call the \noffice or return to the hospital, and all questions were \nanswered. The patient was also given written instructions \nconcerning precautionary instructions and the appropriate \nfollow-up care. The patient expressed readiness for discharge.\n \nMedications on Admission:\nThe Preadmission Medication list is accurate and complete.\n1. Atorvastatin 40 mg PO QPM \n2. Furosemide 20 mg PO DAILY \n3. Hydrocortisone Oint 2.5% 1 Appl TP AS NEEDED FOR RASH ON FACE \n\n4. Levothyroxine Sodium 50 mcg PO DAILY \n5. Lisinopril 40 mg PO DAILY \n6. Metoprolol Succinate XL 25 mg PO DAILY \n7. Omeprazole 20 mg PO DAILY \n8. Acetaminophen ___ mg PO DAILY:PRN Pain - Mild \n9. Calcium 600 + D(3) (calcium carbonate-vitamin D3) 600 \nmg(1,500mg) -400 unit oral 2 tabs daily  \n10. Ferrous Sulfate 325 mg PO BID \n11. Fexofenadine 180 mg PO DAILY:PRN allergies \n\n \nDischarge Medications:\n1.  Bisacodyl 10 mg PO/PR DAILY:PRN Constipation  \n2.  Calcium Carbonate 500 mg PO TID  \n3.  Docusate Sodium 100 mg PO BID  \n4.  Enoxaparin Sodium 30 mg SC Q24H \nStart: Today - ___, First Dose: Next Routine Administration \nTime \nRX *enoxaparin 30 mg/0.3 mL 30 mg subcutaneous daily Disp #*28 \nSyringe Refills:*0 \n5.  OxyCODONE (Immediate Release) 2.5-5 mg PO Q4H:PRN Pain \nRX *oxycodone 5 mg 1 capsule(s) by mouth .___ tablet every 4 \nhours Disp #*42 Capsule Refills:*0 \n6.  Vitamin D 800 UNIT PO DAILY  \n7.  Acetaminophen ___ mg PO DAILY:PRN Pain - Mild  \n8.  Atorvastatin 40 mg PO QPM  \n9.  Calcium 600 + D(3) (calcium carbonate-vitamin D3) 600 \nmg(1,500mg) -400 unit oral 2 tabs daily   \n10.   ...
#  ' \nName:  ___                     Unit No:   ___\n \nAdmission Date:  ___              Discharge Date:   ___\n \nDate of Birth:  ___             Sex:   M\n \nService: MEDICINE\n \nAllergies: \nPatient recorded as having No Known Allergies to Drugs\n \nAttending: ___.\n \nChief Complaint:\nLow Back ___\n \nMajor Surgical or Invasive Procedure:\nNone\n \nHistory of Present Illness:\n___ year old male with chief complaint of severe R leg ___, \nnumbness and weakness, which he has had for the past 6 weeks. \nThe symptoms have been slowly progressive. He describes burning \nsharp ___ that radiates from the right hip to the right knee. \nHis symptoms were not helped or worsened by anything until \nyesterday evening when he stopped being able to ambulate due to \nthe ___. He denies incontinence of urine and bowel. Denies \nhistory of injury. He also is not taking any anticoagulants, and \ndoes NOT endorse any IVDU, nor any personal or familial h/o \ncancer or bone disease.  \n.  \nHe went to the ED on ___, and again on ___ \n- during which he was perscribed valium, ibuprofen, ultram, \ndilaudid, percocet, a short course of prednisone, and physical \ntherapy without much help. He states he has similar ___ a year \nago, for which he was seen on ___ in the context of \nlifting a heavy trash bag at home (relieved with ibuprofen \nalone). Looking even further into his chart, he has been having \nepisodic episodes of similar symptoms for several years, during \nwhich he has been seen by orthopedics and has received several \nXR/MRIs of his Lumbar spine beginning in ___.  \n.  \nOne day prior to admission he presented to the ED for similar \nsymptoms and had a Spine consult, a U/A and ___ control. \nNeurosurgery assessed the patient and decided that the patient \ndid NOT have pathology amenable to surgical intervention. His \nmost recent MRI on ___: demonstrated Lumbar spine MRI \ndisclosed worsening L3-4 R side disc herniation associated with \nsevere narrowing of R foramen. He has a follow up with the ___ \nclinic on ___, which is the soonest the appointment could be \nscheduled. Patient reports taking all ___ medications \nprescribed from ED yesterday w/o effect.  \n.  \nIn the ED: VS: ___. He was treated with \nMorphine 8mg IV, Toradol 30mg IM, and Dilaudid 2mg IV with good \neffect. When he arrived to the floor, the patient appears \ncomfortable and in NAD.  \n.  \n\n \nPast Medical History:\n- Hypercholesterolemia  \n- Insomnia  \n- Hemorrhoids  \n\n \nSocial History:\n___\nFamily History:\nDM, no CA, no blood disorders.\n \nPhysical Exam:\nVS: ___  \nGEN: Comfortable and in NAD  \nHEENT: NC/AT, MMM, OP clear, no LAD  \nCV: RRR, nl S1 and S2, no MRG  \nPULM: CTA-B  \nABD: Soft, NT/ND, BS+, no HSM  \nEXT: No muscle wasting, no midline back tenderness, TTP over \nmusculature of the right femur. Reflexes are ___: patellar, \nachilles and downward going toes; Normal rectal tone; sensation \nis "altered" but present; strength of the LLE is normal and of \nthe RLE is ___ with strong encouragement, but with significant \n___. \n\n \nPertinent Results:\n___ 02:55PM   GLUCOSE-120* UREA N-24* CREAT-0.9 SODIUM-138 \nPOTASSIUM-4.3 CHLORIDE-101 TOTAL CO2-28 ANION GAP-13\n___ 02:55PM   estGFR-Using this\n___ 02:55PM   WBC-9.7# RBC-4.92 HGB-15.9 HCT-44.2 MCV-90 \nMCH-32.4* MCHC-36.1* RDW-12.8\n___ 02:55PM   NEUTS-81.2* BANDS-0 LYMPHS-13.2* MONOS-3.2 \nEOS-0.4 BASOS-0.3\n___ 02:55PM   PLT COUNT-195\n___ 12:20PM URINE  COLOR-Yellow APPEAR-Clear SP ___\n___ 12:20PM URINE  BLOOD-NEG NITRITE-NEG PROTEIN-NEG \nGLUCOSE-NEG KETONE-NEG BILIRUBIN-NEG UROBILNGN-NEG PH-7.0 \nLEUK-NEG\n \nBrief Hospital Course:\n___ year old male with chief complaint of severe R leg ___, \nnumbness and weakness, unable to ambulate.  \n.  \n# Leg ___.  Monitor ___, labs, and obtained \na CK all of which were normal.  Neurosurgery - nothing surgical \nto do at this time.  Acute ___ service consulted.  Pt \ntransitioned from Dilaudid PCA to PO Dilaudid in addition to \nreceiving  ...
#  ' \nName:  ___                   Unit No:   ___\n \nAdmission Date:  ___              Discharge Date:   ___\n \nDate of Birth:  ___             Sex:   F\n \nService: PSYCHIATRY\n \nAllergies: \nTrilafon / Paregoric / Pepto-Bismol / Depakote / Tegretol / \nBromocriptine / Darvocet-N 50 / Clozaril / haloperidol\n \nAttending: ___\n \nChief Complaint:\n"I\'m feeling kinda depressed...my memories of childhood\nhaving flashbacks of my father things he did was awful..I was\nhaving seizures and stuff I started reading and things were\nblurry and I was dropping things and they were slipping out of \nmy\nhands...today I feel sh---y."\n\n \nMajor Surgical or Invasive Procedure:\nnone\n\n \nHistory of Present Illness:\nThe patient is a ___ yo woman, well known to Deaconess ___, \npreviously diagnosed with schizoaffective disorder, s/p numerous \npsychiatric hospitalizations, complex partial seizures who was \nreferred to the ED for evaluation for ongoing seizure activity. \n.\nUpon initial interview, patient reports that she has been having \nincreasing seizures for the past month. She reports that during \nthe episode she will "fade out", have trouble reading due to \nblurry vision, vertigo and slurry speech and related falls. She \nalso reported ongoing auditory hallucinations telling her to \nbite herself and had said that she needed to be "sectioned".\n.\nMs. ___ reports that she has been having "flashbacks" of her \nchildhood abuse perpetrated by her father triggered by the \nHolidays and watching children play with toys. She said "today I \nfel sh---y when the seizure started I kept blurring in and out \nand the depression started with the Holiday Season."\nShe states she spent ___ at her sister\'s and felt that \nher sister was ___ and said " I couldn\'t stand it and \nit gets me angry". She also said that her brother was irritating \nher and she felt the urge " to smash him or break something."\n.\nShe reports that she is having a flashback of one holiday when \nher father was fighting over cider because he wasn\'t served \nfirst and he threw her bother on the porch and his shoes after \nhim. She said "my father was an ___\nThe patient was not able to provide further details of what \nother things might be triggering her today but reports that with \nthe increased in seizure activity she has been having difficulty \nremembering things, focussing has felt dizzy.\n.\nShe denies problems or changes in her sleep, reports decreased \nappetite, poor energy, increased depression abnd irritability \nand feels suicidal with no plan.\n. \n\n \nPast Medical History:\nPAST PSYCHIATRIC HISTORY:\nHospitalizations:Multiple, the most recent @ ___\n___ and admitted to ___ ___ ? discharge\ndates, over the years she has been admitted to ___\nthis past ___.\n___ in ___ after cutting her wrist with\na safety pin while in a waiting room.\nCurrent treaters and ___ ? last name, NP @ ___, Therapist ___ @ ___ in\n___\nMedication and ECT trials:\nSelf-injury:hx of cutting an biting herself\nHarm to others:Reported trying to kill her father by smashing \nhis head against the ground in ___ after she was committed to\na ___ hospital.\nAccess to weapons: denies access to guns\n\nPAST MEDICAL HISTORY:\nPCP ___ ___\nNeurologist Dr. ___ ___\n                                  \nCOMPLEX PARTIAL SEIZURE DISORDER                                \nHEADACHE                                              \nHYPERLIPIDEMIA                                                  \nHYPERTENSION                                                    \nHYPOTHYROIDISM                                                  \nKNEE PAIN                                                       \nLEG PAIN                                                        \nMORBID OBESITY                                                  \nMUSCULOSKELETAL CHRONIC PARANOID                                \nCOMPLEX PARTIAL SEIZURE DISORDER                                \nHEADACHE                                         ...
#  ' \nName:  ___                       Unit No:   ___\n \nAdmission Date:  ___              Discharge Date:   ___\n \nDate of Birth:  ___             Sex:   F\n \nService: MEDICINE\n \nAllergies: \n___ Decongestant\n \nAttending: ___\n \nChief Complaint:\nExertional chest pain\n \nMajor Surgical or Invasive Procedure:\nCoronary angiogram on ___\n\n \nHistory of Present Illness:\n___ ___ only, patient of Dr. ___, with premature\n3v CAD (LAD 30% ISR, Cx 40-50% stenosis, ostial RCA stent ___\nISR), HTN, HLD, DM2 presenting as transfer from ___ with\nchest pain c/f unstable angina. \n\nDiscussed with patient and her family, daughter was translating\nper patient preference.  Patient states that pain started on\n___ while she was at rest.  Substernal chest pain, has been\nintermittent since then.  Worsens with exertion.  At times\nrelieved by rest, but not reliably.  Radiating down left arm.  \nAt\ntimes is it accompanied by nausea.  On ___, she also had a \ndry\ncough.  She also states that she feels dizzy when going from\nsitting to standing.  Has not had any falls or loss of\nconsciousness.\n\nOn review of systems, denies any other concerns including \nfevers,\nchills, recent cold, unintentional weight loss, shortness of\nbreath, hemoptysis, calf pain, lower extremity swelling,\northopnea, PND, palpitations.  No vomiting, diarrhea, dysuria,\nabdominal pain.\n\nAt ___, she was admitted for telemetry monitoring, \nserial\ntroponins were negative and EKGs were unremarkable.  Her pain \nwas\nrelieved with sublingual nitro.  Her flu was negative, her\nd-dimer was normal, and her chest x-ray was reported as clear. \nHer white count was slightly low at 3.7.  Her other basic labs\nwere unremarkable.  Her TSH was low at 0.18, with a normal free\nT4 of 0.94\n\nAlthough she denied this when I spoke with her, she reported\nfevers, chills to MD at ___, and in setting of cough, \nshe\nwas treated with ceftriaxone for bronchitis.  She also reported\npolyuria, polydipsia, urgency, frequency, mild dysuria while she\nwas there, which was also covered with ceftriaxone. Urine \nculture\nwas negative. Her A1c was 13% and her initial glucose was 511. \n\nDespite treatment for suspected URI, her chest pain did not\nresolve, and cardiology at ___ was concerned that she might\nneed a CABG and requested that she be transferred here for cath. \n\nIn her discharge summary, it states that she was "stabilized on\nPlavix" however this is not mentioned in any other notes and was\nnot listed on her discharge medications.\n\nAt ___, several changes were made to her medication list\nincluding discontinuing her Crestor in favor of atorvastatin 80\nmg, and increasing her Lopressor to 50 mg every 12 hours (from \n50\nmg daily). \n\n \nPast Medical History:\nCoronary artery disease/angina, S/P stenting of the LAD & RCA\nHypertension\nDiabetes mellitus\nDyslipidemia\n \nSocial History:\n___\nFamily History:\nThere is no family history of premature coronary artery disease \nor sudden death.  Daughter has sickle cell trait. Multiple \nfamily members with hypertension, DM, hyperlipidemia. Mother had \nuterine cancer.\n \nPhysical Exam:\nADMISSION PHYSICAL EXAM\n=======================\nVS: ___ 2335 Temp: 98.3 PO BP: 143/84 R Sitting HR: 72 RR:\n16 O2 sat: 97% O2 delivery: ra FSBG: 299 \nGENERAL: Well developed, well nourished, NAD, laying comfortably\nHEENT: sclera anicteric, moist mucous membranes\nNECK: JVP of 4 cm\nCARDIAC: Regular rate and rhythm. Normal S1, S2. No murmurs,\nrubs, or gallops. no thrills or lifts.\nLUNGS: No chest wall deformities or tenderness. Respiration is\nunlabored with no accessory muscle use.  Crackles at right base.\nABDOMEN: Soft, non-tender, non-distended. \nEXTREMITIES: Warm, well perfused. No cyanosis edema.\nSKIN: No significant skin lesions or rashes.\nNEURO: AOx3, ___ only, CNII-XII intact, ___ \nstrength\nx4 extremities \n\nDISCHARGE PHYSICAL EXAM\n=======================\n24 HR Data (last updated ___ @ 706)\n    Temp: 98.0 (Tm 98.6), B ...
#  " \nName:  ___                Unit No:   ___\n \nAdmission Date:  ___              Discharge Date:   ___\n \nDate of Birth:  ___             Sex:   M\n \nService: UROLOGY\n \nAllergies: \nNsaids / Xarelto\n \nAttending: ___.\n \nChief Complaint:\nBPH, LUTS\n \nMajor Surgical or Invasive Procedure:\nTRANSURETHRAL RESECTION PROSTATE, BIPOLAR\n\n \nHistory of Present Illness:\n___ year old male with BPH, LUTS presents for TURP. \n \nPast Medical History:\nPMHx:\nCHF (EF 58%)\nHLD\n2nd degree AVB s/p pacer placed ___\nhx/o A Fib\nhx/o SDH\ngastritis\nhearing loss\n\nPSHx: \ncraniotomy\nex lap for duodenal ulcer\ns/p appy\ns/p bilat cataractecomy\n\nDischarge Summary Past Medical History from ___ ___:  \nHypertension, BPH, atrial fibrillation, idopathic pericardial \neffusion, s/pt appendectomy, s/p pericardiocentesis.  \n\n \nSocial History:\n___\nFamily History:\nNoncontributory.\n \nPhysical Exam:\nWDWN male\nconfused at times, pleasant, cooperative\nfoley in place, pink UOP\nno l/e e/p/c/d\n \nPertinent Results:\n___ 06:30AM BLOOD WBC-10.2* RBC-3.26* Hgb-9.3* Hct-28.9* \nMCV-89 MCH-28.5 MCHC-32.2 RDW-15.7* RDWSD-50.9* Plt ___\n___ 06:30AM BLOOD Glucose-124* UreaN-11 Creat-0.8 Na-136 \nK-4.6 Cl-102 HCO3-26 AnGap-13\n\n___ 11:05 am URINE     Site: CYSTOSCOPY      URINE. \n\n                            **FINAL REPORT ___\n\n   URINE CULTURE (Final ___: \n      CORYNEBACTERIUM SPECIES (DIPHTHEROIDS).    >10,000 CFU/ML. \n\n      ENTEROCOCCUS SP..    >10,000 CFU/ML. \n\n                              SENSITIVITIES: MIC expressed in \nMCG/ML\n                      \n_________________________________________________________\n                             ENTEROCOCCUS SP.\n                             |   \nAMPICILLIN------------   <=2 S\nNITROFURANTOIN--------  <=16 S\nTETRACYCLINE----------   <=1 S\nVANCOMYCIN------------     1 S\n\n \nBrief Hospital Course:\nMr. ___ was admitted to Dr. ___ service \nafter bipolar transurethral resection of prostate. No concerning \nintraoperative events occurred; please see dictated operative \nnote for details. Mr. ___ received ___ antibiotic \nprophylaxis and his postoperative course was uncomplicated. He \nreceived intravenous antibiotics and continuous bladder \nirrigation overnight. On POD1 the CBI was discontinued. His \nurine was clear-pink and without clots. He remained a-febrile \nthroughout his hospital stay.  At discharge, Mr. ___ had \npain well controlled with oral pain medications, was tolerating \nregular diet, ambulating and versed on foley care/hygiene.  He \nwas given oral pain medications on discharge and explicit \ninstructions to follow up in clinic for trial of void. He was \ndischarged home with ___ but this service was declined by his \nson. \n \nMedications on Admission:\nThe Preadmission Medication list is accurate and complete.\n1. Finasteride 5 mg PO DAILY \n2. Furosemide 20 mg PO QAM \n3. Metoprolol Succinate XL 25 mg PO BID \n4. Cyanocobalamin 1000 mcg PO DAILY \n5. Tamsulosin 0.4 mg PO QHS \n\n \nDischarge Medications:\n1.  Acetaminophen 650 mg PO Q6H:PRN Pain - Mild  \n2.  Docusate Sodium 100 mg PO BID \nRX *docusate sodium [Colace] 100 mg ONE capsule(s) by mouth \ntwice a day Disp #*60 Capsule Refills:*0 \n3.  Senna 17.2 mg PO HS  \n4.  Cyanocobalamin 1000 mcg PO DAILY  \n5.  Finasteride 5 mg PO DAILY  \n6.  Furosemide 20 mg PO QAM  \n7.  Metoprolol Succinate XL 25 mg PO DAILY  \n8.  Tamsulosin 0.4 mg PO QHS  \n\n \nDischarge Disposition:\nHome\n \nDischarge Diagnosis:\nBenign prostatic hypertrophy. urinary obstruction, urinary \nretention\n\n \nDischarge Condition:\nMental Status: Confused - always.\nLevel of Consciousness: Alert and interactive.\nActivity Status: Ambulatory - requires assistance or aid (walker \nor cane).\n\n \nDischarge Instructions:\n-You may continue to periodically see small amounts of blood in \nyour urine--this is normal and will gradually improve\n\n-Resume your pre-admission/home medications EXCEPT as noted. You \nshould ALWAYS call to infor ...
#  " \nName:  ___                 Unit No:   ___\n \nAdmission Date:  ___              Discharge Date:   ___\n \nDate of Birth:  ___             Sex:   M\n \nService: MEDICINE\n \nAllergies: \nNo Known Allergies / Adverse Drug Reactions\n \nAttending: ___\n \nChief Complaint:\nencephalopathy/malaise\n \nMajor Surgical or Invasive Procedure:\nEGD ___\n\n \nHistory of Present Illness:\nMr. ___ is a ___ yo M patient of Dr. ___ with \nhistory of EtOH cirrhosis s/p combined ___ transplant \nin ___ at ___. He has had multiple ___ biliary \ncomplications. He has had multiple episodes of cholangitis ___ \nstricture c/b bacteremia and septic shock. He has had multiple \nERCP's and CBD stent placements at ___. In ___, he moved his \ncare to ___, where multiple more\nERCP's were performed and ultimately, it was decided to revise \nhis biliary anastomosis with a ___ hepaticojejunostomy. In \n___ he was found to have intrahepatic biliary ductal \ndilation at\nthe proximal common duct and anastomotic stricture on MRCP. On \n___ he received a balloon dilation and \n___\nbiliary stent was placed (which required ___. Liver \nbiopsy on ___ showed chronic rejection. \n\nHe is now ___ for transplant due to being cirrhotic, \nChild's C w/MELD of 31 previously complicated by hepatic \nencephalopathy. His most recent EGD was ___ showing 3 cords \nof grade ___ varices in the lower third of the esophagus. The \nvarices were not bleeding. Additionally he had portal \nhypertensive gastropathy, and esophagitis in lower third of \nesophagus. \n\nHe was recently hospitalized from ___ for hepatic \nencephalopathy and new ___. His symptoms at that time resolved \nwith lactulose, albumin and two units of pRBCs. \n\nThe patient was directly admitted to ___ on ___ due to \nfatigue and encephalopathy, with concern that his hepatic \nfunction may be worsening. Of note the patient had labs drawn on \n___ which were notable for a hemoglobin of 7.4. The rest of \nthe labs were unavailable at the time of interview. \n\nThe patient reports that over the past month he feels he has \nworsening fatigue, that has progressively worsened over the \npreceding week. His confusion has waxed and waned throughout \nthis period somewhat as well, with increasing forgetfulness. The \npatient has been doing a lot of work outside the home and feels \nthat his strength Is decreasing. The patient denies any chest \npain, shortness of breath, abdominal pain, dysuria, cough, \nnausea, vomiting, or fevers. Does get daily chills at home but \nnever had a fever. The patient denies any sick contacts or \nrecent travel. No bloody stools, hemoptysis, hematemesis. The \npatient has baseline loose stools up to ___ per day that have \nbecome more malodorous but have not otherwise changed in \nquality. Of note the patient did have a tick found on his scalp \nyesterday but was present for < 1 hour and was easily removed. \n\nOtherwise a 10 point ROS is negative.\n \nPast Medical History:\n___ gunshot wounds in ___ status post exploratory\nlaparotomy and colostomy.\n___ colostomy was reversed.  \n___, he had a history of ___ obstruction with\nmultiple surgeries that retrieved most of his small bowel.  \n___, laparotomy again had multiple surgeries again for \nsmall\nbowel obstruction.\n___, he had a right knee arthroscopy.\n___, diagnosis of cirrhosis and bleeding varices.  \n___, he had hepatorenal syndrome and liver failure and he\nhad his combined liver and kidney transplant at ___.\nH/o cholangitis, multiple ERCP with plastic/metal stents.\n___ cystoscopy to remove a stent that was placed that was\ncausing urosepsis (this resulted in a lawsuit against ___).  \n___, he underwent a lysis of adhesions at ___.\n___ cholangitis/ s/p ERCP and stent placement.\n___. Hepaticojejunostomy with ___.\n___  PTC and liver biopsy with chronic rejection.\nHepatic encephalopathy\nGout\nDepression\nInsomnia \n \nSocial History:\n___\nFamily History:\nMother - dementia (___)\nFather - diabetes/prostate cancer (___)\ ...
#  ' \nName:  ___                      Unit No:   ___\n \nAdmission Date:  ___              Discharge Date:   ___\n \nDate of Birth:  ___             Sex:   M\n \nService: MEDICINE\n \nAllergies: \nNo Known Allergies / Adverse Drug Reactions\n \nAttending: ___.\n \nChief Complaint:\nWrist pain, swelling\n \nMajor Surgical or Invasive Procedure:\nNone\n\n \nHistory of Present Illness:\nThis is a ___ yo man with history of HIV on Triumeq, IV drug use \nand multiple episodes of cellulitis presenting with two day \nhistory of right wrist pain and swelling. Two days ago he \ninjected crystal meth into right wrist. The following day it \nstarted to hurt and swell. Today he presented to primary care \ndoctor who referred him to ___. Said that he was injecting \nbecause he had bad event in his life recently. He also injected \nin left wrist and antecubital fossa but does not have symptoms \nthere. He reports that he did not have any trauma to the wrist. \nReports having ___ episodes of cellulitis in past. denies \nsystemic infectious symptoms, chest \npain/pressure/sob/n/v/diarrhea/constipation. Took his Triumeq \nthis am. \n  \nIn the ED, initial vitals were: 98.3 70 ___ 100%RA \n \n- Exam notable for: right wrist erythematous, no spread past \nmarking from clinic this morning. No abscess appreciated. Track \nmarks and cut marks up both arms. \n- Labs notable for:  CBC wnl, Chem 10 wnl, lactate 1.8\n- Imaging was notable for:  R wrist Xray: No acute fracture or \ndislocation. Diffuse wrist soft tissue swelling.\n- Patient was given:  Acetaminophen 650 mg, Vancomycin 1000 mg, \nUnasyn 3g\n- Patient was seen by social work who identified that the \npatient was at zero in terms of readiness for treatment.\n\nUpon arrival to the floor, patient reports ongoing pain in his \nright wrist. Denies fever, nausea, vomiting, involvement of any \nother joints. He reports a history of skin abscesses as well as \nbacteremia due to IVDU, but denies a history of endocarditis or \njoint infection. \n \nPast Medical History:\n-HIV\n-IV methamphetamine use with multiple episodes of cellulitis\n-Insomnia\n-Depression\n \nSocial History:\n___\nFamily History:\nNon-contributory\n \nPhysical Exam:\nON ADMISSION\n============\nVITAL SIGNS: 98.6 93/59 64 18 99% Ra \nGENERAL: Appears mildly uncomfortable due to wrist pain; \ngenerally non-toxic appearing\nHEENT: NCAT, moist mucous membranes\nNECK: Supple, no LAD\nCARDIAC: RRR, nl S1/S2, no murmurs\nLUNGS: Clear to auscultation b/l\nABDOMEN: Soft, non-tender, non-distended, no masses\nEXTREMITIES: RUE: multiple injection sites scattered around \nforearm. On volar wrist, small area of erythema with surrounding \nedema. Tender to palpation throughout volar and dorsal forearm. \nNo crepitus. ROM in wrist flexion/extension limited by pain. \nNEUROLOGIC: Moving all extremities equally\nSKIN: On b/l forearms, multiple injection sites with prominent \nscars from cuts on L arm\n\nON DISCHARGE\n============\nVITAL SIGNS: 98.1 PO 115 / 72 L Lying 70 14 95 Ra  \nGENERAL: Comfortable, NAD, anxious appearing\nHEENT: NCAT, moist mucous membranes\nNECK: Supple, no LAD\nCARDIAC: RRR, nl S1/S2, no murmurs\nLUNGS: Clear to auscultation b/l\nABDOMEN: Soft, non-tender, non-distended, no masses\nEXTREMITIES: RUE: multiple injection sites scattered around \nforearm. On volar wrist, trace erythema. Minimally tender to \npalpation throughout volar and dorsal forearm. No crepitus. ROM \n~60 degrees with minimal pain in wrist flexion/extension. \nNEUROLOGIC: Moving all extremities equally\nSKIN: On b/l forearms, multiple injection sites with prominent \nscars from cuts on L arm\n \nPertinent Results:\nADMISSION LABS\n==============\n___ 04:10PM BLOOD WBC-6.7 RBC-4.78 Hgb-14.9 Hct-43.1 MCV-90 \nMCH-31.2 MCHC-34.6 RDW-13.4 RDWSD-43.7 Plt ___\n___ 04:10PM BLOOD Neuts-59.3 ___ Monos-12.7 Eos-1.8 \nBaso-0.3 Im ___ AbsNeut-3.95 AbsLymp-1.72 AbsMono-0.85* \nAbsEos-0.12 AbsBaso-0.02\n___ 04:10PM BLOOD Glucose-113* UreaN-14 Creat-1.1 Na-138 \nK-5. ...
#  ' \nName:  ___                   Unit No:   ___\n \nAdmission Date:  ___              Discharge Date:   ___\n \nDate of Birth:  ___             Sex:   F\n \nService: MEDICINE\n \nAllergies: \nSulfa (Sulfonamide Antibiotics) / clavulanic acid / amoxicillin \n/ levofloxacin\n \nAttending: ___.\n \nChief Complaint:\nhyperglycemia\n \nMajor Surgical or Invasive Procedure:\nendotracheal intubation\ncentral line placement\npercutaneous nephrostomy tube placement\n \nHistory of Present Illness:\nPatient is a ___ female with a past medical history of \ninsulin-dependent diabetes, depression, hypertension, \nhyperlipidemia who presents to the emergency department with \nconcerns for sepsis.\n\nPatient is currently living in a nursing home after multiple \nhospitalizations and has been noncompliant with her medications. \nPer nursing home reports, patient has been having multiple \nepisodes of emesis and has been refusing her medications \nincluding insulin so she was sent for further evaluation. She \npresented to ___ emergency department and there \nwas found to have hyperglycemia with sugars to 700s, VBG ph \n7.4/36.4/41.8/22.3, acetone to 4.1, and  trace ketones in urine) \nso was started on an insulin drip. Lactate went from 2.8 to 5.6, \nWBC to 14.9, and she had a CT of her abdomen done which is \nconcerning for 2 obstructing left proximal ureteral calculi with \nthe largest being 1.1cm, hydronephrosis, and concomitant UTI \nconcerning for an infected stone. CT head negative for acute \nprocess, CXR clear. She was given vancomycin and ceftazidime(and \n___. Per review of records, she received 2 L of LR. Patient \nalso had a CT of her head done with no evidence of intracranial \nhemorrhage. She was transferred here for further care given the \nconcern for sepsis and need for ICU level care.\n\nOn arrival to the ED, history was obtained with help of husband \nand sign language interpreter. She described 2 weeks of not \nfeeling well and having decreased p.o. intake. Her husband has \nbeen concerned for her ability to care for herself and feels \nthat she has depression. She denied any chest pain or pressure, \ndyspnea, dysuria, melena.\n\nED Course notable for:\nInitial vitals: \n99.0 97 158/100 16 95% RA \n\nLabs:\nHCO3 of 21, BUN 52, Cr 2.6, glucose 311 \nCa ___, Mg 1.6, P 1.9 ALT 46, AST 56, ALP 177\nWBC 29, hgb 14.1, plt 159\nINR 1.6, PTT ___ 17.6\nserum tox negative\ntrop 0.05\n\nCK 305, MB 3\n\nLactate 4.7 \nVBG ___\n\nA1c 9.7% \n\nUA: lg leuks, negative nitrite, mod blood, 600 protein, 0 WBC, \nfew bacteria \n\nShe received 1L NS and 500cc LR. \n\nConsults: \nUrology: \nRecommended left percutaneous nephrostomy tube for decompression \nand continue IV abx\n\nTransfer vitals: \n98.2 118 135/75 20 96% RA \n \nOn arrival to the MICU, the patient complained of back pain but \notherwise denied any complaints. Per the patient\'s husband, she \nhas been increasingly confused over the past few weeks. On one \noccasion, she called the police on her husband and accused him \nof abuse even though he had not been home all day.  He says she \nhas not been eating and not taking her pills and she vomits \nafter pill ingestion. \n\n \nPast Medical History:\nType 2 Diabetes Mellitus \nDeafness\nAnxiety\nHypertension\nHypothyroidism\nObesity \n \nSocial History:\n___\nFamily History:\nn/a\n \nPhysical Exam:\nADMISSION PHYSICAL EXAM:\n=================================\nVITALS: Reviewed in metavision  \nGENERAL: Awake, chronically ill appearing, looks older than \nstated age, no acute distress  \nHEENT: Sclera anicteric, MMM, oropharynx clear  \nNECK: supple, JVP not elevated, no LAD  \nLUNGS: Clear to auscultation bilaterally, no wheezes, rales, \nrhonchi  \nCV: Regular rate and rhythm, normal S1 S2, no murmurs, rubs, \ngallops  \nABD: soft, non-tender, non-distended, bowel sounds present, no \nrebound tenderness or guarding, no organomegaly  \nEXT: Warm, well perfused, 2+ pulses, no clubbing, cyanosis or \nedema  \nSKIN: stage 2 ulcer on butt ...
#  ' \nName:  ___.                  Unit No:   ___\n \nAdmission Date:  ___              Discharge Date:   ___\n \nDate of Birth:  ___             Sex:   M\n \nService: PLASTIC\n \nAllergies: \nPatient recorded as having No Known Allergies to Drugs\n \nAttending: ___.\n \nChief Complaint:\nForeign body left proximal tibia\n \nMajor Surgical or Invasive Procedure:\nRemoval foreign body, deep.\nWashout and debridement down to and inclusive of bone.\nApplication of VAC sponge x3\nWashout and debridement down to and inclusive of bone.\nRepair patellar tendon disruption.\nLeft lower leg debridement of skin and subcutaneous fat.\nLeft lower extremity gastrocnemius muscle flap\nLeft lower extremity local advancement closure of donor site.\nLeft lower extremity split-thickness skin graft 20 x 12 cm\n\n \nHistory of Present Illness:\n___ male with a history of a traumatic injury to the \nanterior surface of the tibia with an open wound over patellar \ntendon ___. He underwent a\npatella tendon repair as well. Decision was made to bring him\nto the operating room for repair and wound closure with\ncoverage with gastrocnemius flap and split-thickness skin\ngraft.  \n \nPhysical Exam:\nAVSS\nNAD\nRRR\nCTAB\nABD Soft NT ND\nExt: Skin graft donor site: xeroform partially intact, healing \nwell\nGastroc flap w/ STSG:  Full take, healing well\n\n \nPertinent Results:\n___ 10:45AM BLOOD WBC-10.5# RBC-4.40* Hgb-12.1* Hct-37.5* \nMCV-85 MCH-27.6 MCHC-32.4 RDW-13.2 Plt ___\n___ 10:45AM BLOOD Glucose-101 UreaN-10 Creat-0.7 Na-141 \nK-4.0 Cl-102 HCO3-30 AnGap-13\n___ 10:45AM BLOOD ALT-65* AST-39 AlkPhos-64\n___ 10:45AM BLOOD Calcium-9.1 Phos-3.9 Mg-2.2\n\nCT LEFT LOWER EXTREMITY WITHOUT INTRAVENOUS CONTRAST: \n  \nAt the site of foreign body extraction, there is a large, \napproximately 3.7 x \n1.7 x 1.7 cm osseous defect within the proximal tibia at the \nmetadiaphysis, \nwhich does not involve the tibial articular surface (2:40, \n450A:42). There is \nassociated interruption of the cortex at the anteromedial aspect \nof the tibia, \nwhere tiny locules of gas are seen. There is overlying soft \ntissue defect of \nskin and fat, with packing at the site of surgical debridement. \nThe defect \nextends up to, but does not breach, the posterior tibial cortex. \nNo other \nsbony injury is detected. The patellar tendon appears \nessentially intact, \nconsistent with the history of surgical repair. There is \nexpected surrounding \nsoft tissue edema. A tiny subcentimeter locule of fat is seen \nwithin the \npatellofemoral joint (2:14). \n  \nThe distal tibia and fibula appear normal. The ankle mortise \nintact and \nappears normal. Incidental note is made of an approximately 1.1 \nx 0.9 x 0.5 cm \nintraosseous lipoma of the middle portion of the calcaneus \n(450A:61, 451B:46). \n  \nIMPRESSION: \n  \n1. Proximal tibial osseous and soft tissue defects at site of \nforeign body \nextraction, extending up tp, but not breaching, the posterior \ntibial cortex, \nwith surrounding soft tissue edema. \n  \n2. Intraosseous lipoma of calcaneus incidentally noted.\n\n LEFT KNEE, TWO VIEWS: An 81 x 11 mm radiopaque foreign body is \nseen embedded \nwithin the proximal tibial metaphysis. The object enters the \nbone obliquely \nand measures approximately 1.5 cm at the site of entry. There \nappears to be \nassociated subcutaneous air along the proximal shin; however, \nthis is \ndifficult to definitively visualize due to overexposure of the \nsoft tissue \ncomponents. No joint effusion is seen in the suprapatellar \nspace. The rest \nof the visualized bony structures appear within normal limits. \n  \nIMPRESSION: Foreign object embedded within the proximal tibial \nmetaphysis. \n  \n\n \nBrief Hospital Course:\n___:  To OR by Ortho trauma for removal of foreign object, \ndebridement, VAC\n___:  To OR by Ortho trauma for debridement, VAC, patellar \ntendon repair\n___:  To OR by Plastic surgery for L gastroc flap, debridement, \nSTSG, VAC placement\n___:  Superficial cel ...
#  " \nName:  ___               Unit No:   ___\n \nAdmission Date:  ___              Discharge Date:   ___\n \nDate of Birth:  ___             Sex:   F\n \nService: MEDICINE\n \nAllergies: \nCodeine / Imitrex / Toradol / Aspirin / morphine\n \nAttending: ___.\n \nChief Complaint:\nabdominal pain\n \nMajor Surgical or Invasive Procedure:\nNA\n \nHistory of Present Illness:\n___ year old female PMH of CVA (paraplegic with neurogenic \nvoiding dysfunction), RA, lupus, possible Crohn's (not \nconsistent pathology on prior admission), chronic abdominal pain \n(multiple SBOs s/p subtotal colectomy), nephrolithiasis, DM2, \nanxiety, and depression, narcotics dependence, now s/p SPT \nreplacement on ___ with new onset abdominal symptoms and pain. \n  \n\nThe patient has been having lower abdominal pain and has been \nhaving bilateral lower back pain. The patient has intermittent \nobjective fevers to 102 during this time. The patient otherwise \nis having some chills. The patient states that there has been \nurine leaking around the suprapubic cath. She went to ___ \n___ and started on PO ABx for UTI (Keflex). The patient had \na CT scan at ___ which was unremarkable, but as she has had \ncontinued pain and UTI symptoms. She had an initial lactic of \n3.0 that improved after fluids. \n\nPertinent ED course:\nInitial vitals: T98.5, HR 108, BP 122/97, RR 18, 97% Ra\n\nExam: redness around suprapubic site with significant \ntenderness, afebrile during entire ED stay\n\nRelevant labs: \nBMP: Na 138, K 4.1, Cl 102, HCO3 21, BUN 8, Cr 0.7\nCBC: WBC 12.0, Hgb 11.6, platelets 224\nUA: cloudy with large leuk, mod blood, nitrate positive, protein \n600, gluc 150, RBC 78, WBC 182, Bact many\nBcx and ucx pending\n\nPatient was given:\n- Hydromorphone 1 mg x 8\n- NS 2 L\n- Cefepime 2g \n- Acetaminophen 1 g x2\n- Insulin \n\nConsult: urology\n \nVitals on transfer: T97.8, HR 102, BP 107/73, RR 16, 98% Ra\n\nUpon arrival to the floor, the patient reports that she is in \nterrible pain. She says this is significantly worse than pain \nshe has had on prior admissions. She says it is nothing like her \nadmission in ___ for similar complaints.  The patient \nreports she has had fevers at home up to 102. She says the pain \nstarted right after her procedure on ___. It has only gotten \nworse since then. She notes headache, chills, no rigors, no \nlightheadedness. She notes the catheter was draining red liquid \nand now it is clear. Her appetite is decreased and she has had \nsome nausea and vomiting. She states she has been having normal \nbowel movements and that this does not feel like her prior small \nbowel obstructions.\n\nShe says she has both pain and anxiety right now. She says she \ntakes Xanax up to 3x a day. \n\nThe patient states she knows her medications and doses, but on \nreview of her medications the only thing she is able to share is \nshe is not taking her methotrexate right now because she is \nworried she is infected. She has confusion surrounding some of \nher meds including atorvastatin that she said she discontinued, \nand paroxetine she says she may be taking 2x a day. She says she \ntook all 40 of her oxycodone within the first week or so after \nher catheter placement.   \n \nREVIEW OF SYSTEMS:  \n(+) per HPI\n(-) for chest pain, palpitations, shortness of breath, cough\n\n \nPast Medical History:\n 1. Seropositive rheumatoid arthritis.  \n 2. ?SLE diagnosed in ___ in the setting of Humira. Never on  \n hydroxychloroquine. No kidney biopsy or history of nephritis.  \n 3. ?Crohn's disease complicated by multiple small bowel  \n obstructions.  \n 4. CVAs and ?spinal cord infarct in ___ cardiac \narrest, resulting in bilateral lower extremity paralysis, atonic \nbladder now s/p SPT  \n 5. Diabetes diagnosed at age ___.  \n 6. Depression.  \n 7. Insomnia.  \n 8. Narcotic dependence.  \n 9. ___ femoral head avascular necrosis  \n \nSocial History:\n___\nFamily History:\nMother - RA, DM\nFather - CAD, DM, RA\nMGM - RA, DM\nPGM - RA, DM\ ...
#  ' \nName:  ___               Unit No:   ___\n \nAdmission Date:  ___              Discharge Date:   ___\n \nDate of Birth:  ___             Sex:   M\n \nService: MEDICINE\n \nAllergies: \nPenicillins\n \nAttending: ___.\n \nChief Complaint:\nAnorexia, nausea, vomiting, diffuse pruritus x 1 month, found to \nhave hypertensive urgency\n \nMajor Surgical or Invasive Procedure:\nTunneled hemodialysis line placement \n\n \nHistory of Present Illness:\nMr. ___ is a ___ year-old male with history of diabetes \nmellitus (last A1c was 6.36% in ___ complicated by \nnephropathy, retinopathy, s/p PRP (___), HTN, HLD, CKD stage \nIV s/p RUE AVF placement (___), OSA, MDD, and schizophrenia \nwho presents with anorexia, nausea, vomiting, and diffuse \npruritis for 1 month. He has had relatively quick progressive \nrenal dysfunction believed to be secondary to diabetic \nnephropathy. Patient has had multiple recent admissions related \nto volume overload. He was seen by his nephrologist, Dr ___ \non ___ complaining of these same symtpoms. Dr. ___ \n___ Mr. ___ to be directly admitted for HD \ninitiation, but he reports that he "had things to take care of." \nHe reports that he is now ready to initiate HD. He denies chest \npain, shortness of breath, dysuria, hematuria. He does note \nincreased urine volume after increasing his diuretic. He has \nnoticed a corresponding decrease in his ___ edema. He did not \ntake his medications this morning however. Related to this, he \nhas an occasional "funny" sensation on his right thumb, but no \nsymptoms consistent with steal.  \n\nThe patient is additionally reporting orthopnea and paroxysmal \nnocturnal dyspnea. He denies chest pain, abdominal pain, bowel \nor bladder changes (although he does note dark urine lately). Pt \nhad AVF placed on ___, which is not yet mature.  \n\n \nPast Medical History:\n-CHF/Cardiomyopathy: Mild systolic and severe diastolic \ndysfunction.  \n-Diabetes  \n-Hypertension  \n-Hypercholesterolemia  \n-CKD, stage 3  \n-Depression/Schizophrenia  \n-OSA  \n \nSocial History:\n___\nFamily History:\nMother and maternal grandmother had diabetes and both used \ninsulin.  Mother died of cancer. Grandfather (maternal) also has \ndiabetes. Father is alive at ___. He does not know his father\'s \nhealth  status. No early CAD or sudden cardiac death.\n \nPhysical Exam:\nOn admission: \nVitals - T: 98.5 BP: 190/94 HR: 80 RR: 16 02 sat: 99%RA  \nGen: Young man lying comfortably in bed, in no acute distress  \nHEENT: No conjunctival pallor. No icterus. MMM. OP clear. \nDecreased vision in right eye.  \nNECK: Supple, No LAD. JVP 12. Normal carotid upstroke without \nbruits. No thyromegaly.  \nCV: RRR. normal S1, loud P2. ___ HSM at ___  \nLUNGS: Crackles bilateral bases. No wheezes. Breathing \ncomfortably.  \nABD: Nondistended, +BS, nontender in all quadrants, no \nrebound/guarding, no hepatosplenomegaly  \nEXT: WWP, 1+ edema bilaterally. Full distal pulses bilaterally.  \n\nNo femoral bruits. Right AV fistula in the patient\'s wrist with \na palpable thrill.  \nSKIN: No rashes/lesions, ecchymoses.  \nNEURO: A&Ox3. CN ___ grossly intact. Preserved sensation  \nthroughout. ___ strength throughout. ___ reflexes, equal ___.  \n\nOn discharge:\nVS - Temp 98.3 BP 174/72 HR 72 RR 18 SpO2 95% RA  \nGeneral: well-appearing, NAD  \nHEENT: MMM, EOMI right, left eye closed without eye patch  \nNeck: Supple. JVP at angle of mandible.  \nCV: RRR, S1/S2, I/VI systolic murmur at left sternal border  \nLungs: Crackles right base > left base. Good air movement.  \nAbdomen: Obese. Soft, nontender. +BS. No palpable masses.  \nExt: No cyanosis. Trace edema bilaterally to mid-calf. Bilateral \nradial pulses 2+, palpable thrill and bruit auscultated over R \nforearm AV fistula  \nNeuro: CN grossly intact. Vision decreased in right eye (patient \nstates chronic)  \nSkin: Xerosis over bilateral legs. No rashes or other lesions.  \n\n \nPertinent Results:\nOn admission:\n___ 12:45PM BLOOD WBC-5.3 RBC-2.72* Hgb-8 ...
#  ' \nName:  ___                   Unit No:   ___\n \nAdmission Date:  ___              Discharge Date:   ___\n \nDate of Birth:  ___             Sex:   F\n \nService: MEDICINE\n \nAllergies: \nNo Known Allergies / Adverse Drug Reactions\n \nAttending: ___\n \nChief Complaint:\ncough and shortness of breath\n \nMajor Surgical or Invasive Procedure:\nnone\n \nHistory of Present Illness:\nMs. ___ is a ___ woman with a history of autoimmune hepatitis\non chronic prednisone, HTN, severe COPD, lung nodules\nrepresenting likely lung cancer planned for biopsy, and remote\nPE, presenting with 2 weeks of increasing cough and shortness of\nbreath.  \n\n Patient reports not feeling well for the past two weeks, with\nintermittent chills, increased coughing and sputum production,\nand weakness. She also noticed streaks of blood in her sputum a\ncouple of days ago. She has had mild nausea, although no\nvomiting, diarrhea or abdominal pain. Does not endorse myalgias.\nShe also endorses "foul smelling urine" for about a week, but no\ndysuria. She lives alone at baseline and is fully functional,\nalthough says she has not been eating for the last two weeks,\nalthough she has been drinking minimally and taking her meds. \nHer\nson was "really sick" about two weeks ago, just at the onset of\nher symptoms, although never required medical care. Of note, she\nhas been followed here at ___ for lung nodules, and is planned\nfor a VATS with Dr. ___ on ___.  \n\n In the ED, initial VS were: T 98.1, HR 65, BP 128/71, RR 20,  \n 95% RA  \n Exam notable for:  \n Gen- Weak appearing, although not in acute distress  \n Chest- Diminished lung sounds bilaterally, inspiratory wheezes  \n\n Abd- Soft, non-tender, non-distended  \n Ext- Trace lower extremity edema  \n Labs showed:  \n - CBC: WBC 9.8, Hgb 13.0, Hct 40.8, Plt 312  \n \n - Lytes:  \n 145 / 106 / 30  \n -------------- 122  \n 6.2 \\ 18 \\ 1.1  \n - proBNP: 285  \n - Lactate:2.3  \n - repeat K 5.2  \n Imaging notable for CXR showing:  \n \n 1. No new focal opacities suggest pneumonia.  \n 2. Redemonstrated cavitary left upper lobe lesion is difficult\nto compare prior chest CT and may have slightly grown. This \ncould\nbe further evaluated with nonemergent noncontrast chest CT, if\nindicated.  \n 3. Emphysema.  \n \n Patient received:  \n /___ 00:28 IH Albuterol 0.083% Neb Soln 1 NEB  \n ___ 00:28 IH Ipratropium Bromide Neb 1 NEB  \n ___ 00:53 IVF NS Started  \n ___ 01:00 IVF NS 1000 mL Stopped (___)  \n ___ 02:41 IH Albuterol 0.083% Neb Soln 1 NEB  \n ___ 02:41 IH Ipratropium Bromide Neb 1 NEB  \n ___ 03:10 PO Benzonatate 100 mg  \n ___ 03:10 IV Azithromycin 500 mg  \n ___ 03:10 PO PredniSONE 60 mg  \n\n Transfer VS were: T 98.0, HR 102, BP 98/79, RR 22, 95% RA  \n \nPast Medical History:\n-COPD\n-Autoimmune Hepatitis (stage 1 fibrosis)\n-Perforation during colonoscopy in ___ requiring ex lap \n-Pulmonary Embolism ___ (provoked by surgery above)\n-Systolic Dysfunction on echo (EF 45% ___ but no CHF \nhistory\n-Osteoporosis\n-GERD\n-Anemia\n-S/p Cholecystectomy \n\n \nSocial History:\n___\nFamily History:\nHeart disease\nDiabetes mellitus\n \nPhysical Exam:\nADMISSION EXAM: \nVital Signs: 24 HR Data (last updated ___ @ 1444)\n    Temp: 98.1 (Tm 98.6), BP: 117/76 (113-122/70-77), HR: 88\n(88-100), RR: 20 (___), O2 sat: 97% (95-97), O2 delivery: RA,\nWt: 153.9 lb/69.81 kg   \nGeneral: calm, NAD\nHEENT: OP clear, no LAD\nCV: RRR, no murmurs\nPULM: Markedly decreased air movement in all lung ___ without\nwheezing, no rales, no asymmetry\nABD: obese, soft, NT, ND\nEXT: No ___ edema, WWP\n\nDISCHARGE EXAM:\n24 HR Data (last updated ___ @ 032)\n    Temp: 98.4 (Tm 98.6), BP: 118/73 (106-128/69-80), HR: 76\n(76-130), RR: 22 (___), O2 sat: 98% (90-98), O2 delivery: Ra  \n\nGeneral: alert, oriented, no acute distress\nEyes:  Sclera anicteric\nHEENT: MMM, oropharynx clear  \nNeck: supple, no LAD  \nResp: clear to auscultation bilaterally, distant breath sounds,\nimproved air movement, faint crackles b/l at the ba ...
#  " \nName:  ___                  Unit No:   ___\n \nAdmission Date:  ___              Discharge Date:   ___\n \nDate of Birth:  ___             Sex:   M\n \nService: MEDICINE\n \nAllergies: \nNo Known Allergies / Adverse Drug Reactions\n \nAttending: ___.\n \nChief Complaint:\nFever\n \nMajor Surgical or Invasive Procedure:\nNone\n\n \nHistory of Present Illness:\n___ h/o DM2 (uncontrolled), poorly differentiated Gastric CA \nT2N0Mx s/p subtotal gastrectomy ___ admitted with fever, \nweakness.  At baseline, reports that his sugar has been labile \nwith BS intermittently going high to 300s.  Nearly ___ days ago, \ndeveloped cough, sore-throat, fevers, associated with worsened \nhyperglycemia 400's.  Also notes having concurrent dysuria.  \nReports 3d ago developing temp to 103 and then 2d PTA temp 102.  \nHe went to PCP yesterday and noted to be hypotensive to the \n___, unwell.  As a result, was sent to the ED.\n   In the ED, reportedly he was no longer hypotensive.  WBC \n11.1, CXR neg, U/A with ___ large, Nit neg, WBC 15.  He was given \ntotal of 3.5 L IVF over span of ED stay and given vanc/zosyn for \nempiric coverge (presumed urosepsis).   He was admitted for \nfurther mgmt.\n  \n\nROS: per HPI, denies night sweats, headache, vision changes, \nrhinorrhea, congestion, shortness of breath, chest pain, \nabdominal pain, nausea, vomiting, diarrhea, constipation, BRBPR, \nmelena, hematochezia, hematuria.  A 10 pt review of sxs was \notherwise negative.\n\n \nPast Medical History:\n# Hyperchol\n# DM2 - uncontrolled, mild retinopathy\n# poorly differentiated Gastric CA with signet ring features \nT2N0Mx\n - s/p 6 cycles of ECF completed ___\n - s/p robotic-assisted subtotal gastrectomy with RNY \nreconstruction, radical lymphadenectomy ___\n# Asthma\n# Spinal stenosis\n# BPH s/p prostate surgery x2\n# Anxiety/depression\n# Compression fx L1 Lumbar vertebra\n \nSocial History:\n___\nFamily History:\nFamily History: sister - eye cancer, father - prostate cancer\nMother- T2 diabetes, MI in ___\n \nPhysical Exam:\nADMISSION PHYSICAL EXAM\nVital Signs: 98.0  154/75  96 20 98% RA \nGEN: NAD, well-appearing, lying in bed, interactive, pleasant\nEYES: PERRL, EOMI, conjunctiva clear, anicteric\nENT: moist mucous membranes, no exudates \nNECK: supple \nCV: RRR s1s2 nl, no m/r/g\nPULM: CTA, no r/r/w \nGI: normal BS, NT/ND, no HSM, no CVAT  \nEXT: warm, no c/c/e\nSKIN: no rashes \nNEURO: alert, oriented x 3, answers ? appropriately, follows \ncommands, non focal\nPSYCH: appropriate\nACCESS: PIV\nFOLEY: absent\n\nDISCHARGE PHYSICAL EXAM\nVS: 97.9 165/80 81 18 95 RA \nGEN: NAD, well-appearing, lying in bed, interactive, pleasant\nEYES: anicteric, non-injected\nENT: MMM, grossly nl OP. No tonsilar euxudates, no significant \nerythema or coblestoning. \nNECK: supple, non meningismus, no LAD\nBACK: no spinous process tenderness, no CVAT\nCV: RRR nl S1/S2 no g/r/m 2+ rad/DP pulses\nCHEST: CTAB no w/r/r\nABD: soft, NT/ND, NABS, no HSM. CGM in LLQ, no erythema\nGU: no suprapubic fullness/tenderness. \nEXT: warm, no c/c/e, no joint effusions. \nSKIN: no rashes \nNEURO: alert, oriented x 3. moves all extremities spontaneously \nand with purpose. Facial movements symmetrical, speech fluent, \neyes conjugate, sensation to light touch preserved grossly. \nPSYCH: pleasant and appropriate\n \nPertinent Results:\nADMISSION LABS:\n___ 04:05PM BLOOD WBC-11.1* RBC-4.48* Hgb-12.2* Hct-38.6* \nMCV-86 MCH-27.2 MCHC-31.6* RDW-14.4 RDWSD-45.7 Plt ___\n___ 04:05PM BLOOD Neuts-65.3 Lymphs-18.3* Monos-15.5* \nEos-0.4* Baso-0.3 Im ___ AbsNeut-7.26* AbsLymp-2.04 \nAbsMono-1.72* AbsEos-0.05 AbsBaso-0.03\n___ 04:05PM BLOOD ___ PTT-34.3 ___\n___ 04:05PM BLOOD Plt ___\n___ 04:05PM BLOOD Glucose-129* UreaN-29* Creat-1.1 Na-141 \nK-3.9 Cl-102 HCO3-27 AnGap-12\n___ 04:05PM BLOOD ALT-29 AST-26 AlkPhos-66 TotBili-0.4\n___ 04:05PM BLOOD Albumin-4.1\n___ 04:18PM BLOOD ___ pO2-28* pCO2-57* pH-7.34* \ncalTCO2-32* Base XS-1\n___ 04:18PM BLOOD Lactate-2.5*\n___ 04:18PM BLOOD O2 Sat-4 ...

# %%
# Here everything is done dont worry
# replacement of None Values Exercise
def replace_placeholders(text, placeholder="___", replacement="None"):
    return text.replace(placeholder, replacement)

# Extracting key information using regex
def extract_information(text):
    info = {}
    patterns = {
        "Name": r"Name:\s+(.*?)\s+Unit No",
        "Unit No": r"Unit No:\s+(.*?)\n",
        "Admission Date": r"Admission Date:\s+(.*?)\s+Discharge Date",
        "Discharge Date": r"Discharge Date:\s+(.*?)\n",
        "Date of Birth": r"Date of Birth:\s+(.*?)\s+Sex",
        "Sex": r"Sex:\s+(\w)",
        "Service": r"Service:\s+(.*?)\n",
        "Allergies": r"Allergies:\s+(.*?)\n",
        "Chief Complaint": r"Chief Complaint:\n(.*?)\n",
        "Major Surgical or Invasive Procedure": r"Major Surgical or Invasive Procedure:\n(.*?)\n",
        "History of Present Illness": r"History of Present Illness:\n(.*?)\n\n",
        "Review of systems": r"Review of systems:\s+(.*?)\n\n",
        "Past Medical History": r"Past Medical History:\n(.*?)\n\n",
        "Social History": r"Social History:\n(.*?)\n",
        "Family History": r"Family History:\n(.*?)\n\n",
        "Physical Exam": r"Physical Exam:\n(.*?)\n\n",
        "Brief Hospital Course": r"Brief Hospital Course:\n(.*?)\n\n",
        "Discharge Diagnosis": r"Discharge Diagnosis:\n(.*?)\n\n",
        "Discharge Condition": r"Discharge Condition:\n(.*?)\n\n",
        "Discharge Instructions": r"Discharge Instructions:\n(.*?)\n\n",
    }

    for key, pattern in patterns.items():
        match = re.search(pattern, text, re.DOTALL)
        info[key] = match.group(1).strip() if match else "None"
        
    return info
def structure_data(clinical_text):
    # Replace placeholders in the clinical text
    processed_text = replace_placeholders(clinical_text)

    # Extract information into a dictionary
    return extract_information(processed_text)

structure_notes = [ structure_data(note) for note in notes]

# %% [markdown]
# # Null values treatment

# %%
df = pd.DataFrame(structure_notes).replace('None',np.nan)
df.head(3)
# Out:
# C:\Users\Utilizador\AppData\Local\Temp\ipykernel_6512\2895082975.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = pd.DataFrame(structure_notes).replace('None',np.nan)
#   Name  Unit No  Admission Date  Discharge Date  Date of Birth Sex  \
# 0  NaN      NaN             NaN             NaN            NaN   F
# 1  NaN      NaN             NaN             NaN            NaN   M
# 2  NaN      NaN             NaN             NaN            NaN   F
#
#         Service                                    Allergies Chief Complaint  \
# 0      MEDICINE                                      Codeine    I feel shaky
# 1      MEDICINE                                      Demerol         Dyspnea
# 2  ORTHOPAEDICS  No Known Allergies / Adverse Drug Reactions        RLE pain
#
#      Major Surgical or Invasive Procedure  \
# 0                                     NaN
# 1                            Bronchoscopy
# 2  Right short trochanteric fixation nail
#
#                           History of Present Illness  \
# 0  Pt is a None year old woman who presents to ED...
# 1  This is an None yo M with history of mild deme...
# 2  None, blown over by gust of wind w/R ITFx now ...
#
#                                    Review of systems  \
# 0  (+) Per HPI. Also notes recent weight gain whi...
# 1                                                NaN
# 2                                                NaN
#
#                                 Past Medical History  Social History  \
# 0  -IDDM c/b retinopathy\n-HTN\n-AFib, diagnosed ...             NaN
# 1  gastroesophageal reflux disease\nhypercholeste...             NaN
# 2  MedHx:\n-HTN\n-Hypercholesterolemia\n-Eczema\n...             NaN
#
#                                       Family History  \
# 0  - 6 children, one daughter died last year from...
# 1  strong family history of diabetes mellitus, an...
# 2  Mother deceased with HTN, CAD. Father deceased...
#
#                                        Physical Exam  \
# 0  FEX ON ADMISSION\nVitals: T: 98.4 BP: 176/96 P...
# 1  VS: T 98.6max, 97.3current, BP None, HR 79 RR ...
# 2                                                NaN
#
#                                Brief Hospital Course  \
# 0  None year old woman with IDDM and AFib on coum...
# 1  None year old  male with complaints of dyspnea...
# 2  The patient presented to the emergency departm...
#
#                                  Discharge Diagnosis  \
# 0  Lactic acidosis\nHyperglycemia\nUrinary tract ...
# 1            Lung mass\nAcute renal failure\nHypoxia
# 2             right intertrochanteric femur fracture
#
#                                  Discharge Condition  \
# 0  Mental Status: Clear and coherent.\nLevel of C...
# 1                    Stable, for home with services.
# 2                AAOx3, mentating appropriately, NVI
#
#                               Discharge Instructions
# 0                                     Dear Ms. None,
# 1  You were admitted to the hospital because of y...
# 2  Weigh yourself every morning, call MD if weigh...

# %%
df.isnull().sum()
# Out:
# Name                                    14
# Unit No                                 15
# Admission Date                          15
# Discharge Date                          15
# Date of Birth                           15
# Sex                                      0
# Service                                  0
# Allergies                                0
# Chief Complaint                          0
# Major Surgical or Invasive Procedure     4
# History of Present Illness               0
# Review of systems                       14
# Past Medical History                     1
# Social History                          15
# Family History                           1
# Physical Exam                            1
# Brief Hospital Course                    1
# Discharge Diagnosis                      0
# Discharge Condition                      0
# Discharge Instructions                   0
# dtype: int64

# %%
# Drop columns with nan values
df_treated = df.dropna(axis=1)

# %% [markdown]
# # Complete yourself

# %%
# Lets start building a corpus
discharged_diagnosis = ' '.join(df_treated['Discharge Diagnosis'].to_list())

# %%
# Function to clean individual lines
def clean_line(line):
    # Remove HTML-like tags
    line = NotImplementedError
    # Remove unwanted characters (e.g., non-ASCII characters)
    line = re.sub(r'[^\x00-\x7F]+', '', line)
    # Strip leading/trailing whitespace
    return line.strip()

def speaking_text_cleaner(speaking_text):
    # Process each line to clean it
    cleaned_lines = []
    for line in speaking_text.splitlines():
        cleaned_line = clean_line(line)
        if cleaned_line:  # Only add non-empty lines
            cleaned_lines.append(cleaned_line)
    return "\n".join(cleaned_lines)

cleaned_discharged_diagnosis = speaking_text_cleaner(discharged_diagnosis)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 19
#      16             cleaned_lines.append(cleaned_line)
#      17     return "\n".join(cleaned_lines)
# ---> 19 cleaned_discharged_diagnosis = speaking_text_cleaner(discharged_diagnosis)
#
# Cell In[14], line 14, in speaking_text_cleaner(speaking_text)
#      12 cleaned_lines = []
#      13 for line in speaking_text.splitlines():
# ---> 14     cleaned_line = clean_line(line)
#      15     if cleaned_line:  # Only add non-empty lines
#      16         cleaned_lines.append(cleaned_line)
#
# Cell In[14], line 6, in clean_line(line)
#       4 line = NotImplementedError
#       5 # Remove unwanted characters (e.g., non-ASCII characters)
# ----> 6 line = re.sub(r'[^\x00-\x7F]+', '', line)
#       7 # Strip leading/trailing whitespace
#       8 return line.strip()
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\re\__init__.py:185, in sub(pattern, repl, string, count, flags)
#     178 def sub(pattern, repl, string, count=0, flags=0):
#     179     """Return the string obtained by replacing the leftmost
#     180     non-overlapping occurrences of the pattern in string by the
#     181     replacement repl.  repl can be either a string or a callable;
#     182     if a string, backslash escapes in it are processed.  If it is
#     183     a callable, it's passed the Match object and must return
#     184     a replacement string to be used."""
# --> 185     return _compile(pattern, flags).sub(repl, string, count)
#
# TypeError: expected string or bytes-like object, got 'type'

# %%
def corpus_cleaner(cleaned_text,n_min = 4 ):
    n_min = 4                                                           # Minimum number of characters. 
    corpus = []
    lemmatizer = WordNetLemmatizer()

    pre = re.sub(r'\W', ' ', cleaned_text)                          # Substitute the non-alphanumerics character by space. 
                                        # Remove numbers.                                      # Exercise
    pre = nltk.word_tokenize(pre)                                   # Tokenize into words.                                 # Exercise
    pre = [x for x in pre if len(x) > n_min]                        # Minimum length.
    pre = [x.lower() for x in pre]                                  # Convert into the lowercase.
    pre = [x for x in pre if x not in stopwords.words('english')]   # Remove stopwords.
    pre = [lemmatizer.lemmatize(x) for x in pre]                    # Lemmatize.
    corpus += pre                                                   # Back to the corpus.
    return corpus

# %%
corpus_clean  = corpus_cleaner( cleaned_discharged_diagnosis )

# %% [markdown]
# # Count the words

# %%
from collections import Counter

# choose words you want to remove
remove_words = ['primary','secondary','going','diagnosis','right']
  = [x for x in corpus_clean if x not in remove_words]
pd.Series(Counter(corpus_clean)).sort_values()[-50:].plot(kind='bar')

# %% [markdown]
# # Word Cloud

# %%
a_long_sentence = ' '.join(treated_corpus)
wc = WordCloud(background_color='white', max_words=70,colormap='gist_gray')                  # Customize the output.
wc.generate(a_long_sentence)
# wc.words_                                                          # Check for the top ranking words.                                                         
plt.figure(figsize=(10,10))
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")                                    # Turn off the axes.
#plt.savefig('clinical_notes.png',bbox_inches='tight')
plt.show()
